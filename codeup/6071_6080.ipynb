# %%
#6071
a = int(input())

while a!=0:
    print(a)
    a = int(input())
# Out:
# 7
# 7
# 4
# 4
# 2
# 2
# 3
# 3
# 0

# %%
#6072
a = int(input())
while a!=0:
    print(a)
    a-=1
# Out:
# 5
# 5
# 4
# 3
# 2
# 1

# %%
#6073
a = int(input())
while a!=0:
    print(a-1)
    a-=1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
ord('b')
# Out:
# 98

# %%
#6074
char = ord(input())
a = ord('a')# ord('a') = 97, ord('b') = 98 ,...
while a<=char:
    print(chr(a),end=' ')
    a+=1
# Out:
# f
# a b c d e f

# %%
#6075
a = int(input())
for i in range(0,a+1):
    print(i)
# Out:
# 4
# 0
# 1
# 2
# 3
# 4

# %%
#6075-while문
a = int(input())
i=0
while i<=a:
    print(i)
    i+=1
# Out:
# 4
# 0
# 1
# 2
# 3
# 4

# %%
#6076
a = int(input())
for i in range(0,a+1):
    print(i)
# Out:
# 4
# 0
# 1
# 2
# 3
# 4

# %%
#6077
a = int(input())
s = 0
for i in range(1,a+1):
    if i%2==1:
        continue
    else:
        s+=i
print(s)
# Out:
# 5
# 6

# %%
#6078
while True:
    c = input()
    print(c)
    if c =='q':
        break
# Out:
# x
# x
# c
# c
# q
# q

# %%
#6079
a = int(input())
s = 0
i=0
while True:
    i+=1
    s+=i
    if s>=a:
        print(i)
        break
# Out:
# 55
# 10

# %%
#6080
n,m = map(int,input().split())

for i in range(1,n+1):
    for j in range(1,m+1):
        print(i,j)
# Out:
# 2 3
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
