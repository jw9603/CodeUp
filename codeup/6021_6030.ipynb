# %%
#6021
c = input()
for i in c:
    print(i)
# Out:
# hello
# h
# e
# l
# l
# o

# %%
#6022
a = input()

for i in range(0,len(a),2):
    print(a[i],a[i+1],sep='',end=' ')
# Out:
# 200304
# 20 03 04

# %%
#6023
h, m, s = input().split(':')
print(m)
# Out:
# 17:23:57
# 23

# %%
#6024
a,b = input().split()
print(a+b)
# Out:
# hello world
# helloworld

# %%
#6025
a,b = map(int,input().split())
print(a+b)
# Out:
# 123 -123
# 0

# %%
#6026
a = float(input())
b = float(input())
print(a+b)
# Out:
# 0.1
# 0.9
# 1.0

# %%
#6027
a = int(input())
print('%x'%a)
# Out:
# 255
# ff

# %%
#6028
a = int(input())
print('%X'%a)
# Out:
# 255
# FF

# %%
#6029
a = int(input(),16)
print('%o'%a)
# Out:
# f
# 17

# %%
#6030
a = ord(input()) # ord(c)는 문자의 유니코드 값을 돌려주는 함수이다.
# ord 함수는 chr 함수와 반대이다.
#chr는 유니코드 값을 입력받아 그 코드에 해당하는 문자를 출력하는 함수이다.
print(a)
# Out:
# A
# 65
