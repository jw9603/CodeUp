# %%
#6001
print('Hello')
# Out:
# Hello

# %%
#6002
print('Hello World')
print('Hello',end=' ')
print('World')
# Out:
# Hello World
# Hello World

# %%
#6003
print('Hello\nWorld')
# Out:
# Hello
# World

# %%
#6004
print("\'Hello\'")
# Out:
# 'Hello'

# %%
#6005
print("\'Hello World\'")
# Out:
# 'Hello World'

# %%
#6006
print('\"!@#$%^&*()\'')
# Out:
# "!@#$%^&*()'

# %%
#6007
print('\"C:\\Download\\\'hello\'.py\"')
# Out:
# "C:\Download\'hello'.py"

# %%
#6008
print('print("Hello\\nWorld")')
# Out:
# print("Hello\nWorld")

# %%
#6009
a = input()
print(a)
# Out:
# 5
# 5

# %%
#6010
a = int(input())
print(a)
# Out:
# 15
# 15
