# %%
#6011
a = float(input())
print(a)
# Out:
# 1.4564854
# 1.4564854

# %%
#6012
a = int(input())
b = int(input())
print(a)
print(b)
# Out:
# 1
# 2
# 1
# 2

# %%
#6013
a = input()
b = input()
print(b)
print(a)
# Out:
# d
# f
# f
# d

# %%
#6014
f = float(input())
print(f,f,f,sep='\n')
# Out:
# 0.1
# 0.1
# 0.1
# 0.1

# %%
#6015
a,b = map(int,input().split())
print(a,b,sep='\n')
# Out:
# 1 2
# 1
# 2

# %%
#6016
a,b = map(str,input().split())
print(b,a)
# Out:
# a b
# b a

# %%
#6017
a = input()
print(a,a,a)
# Out:
# computer science
# computer science computer science computer science

# %%
#6018
a,b = input().split(':')
print(a,b,sep=':')
# Out:
# 3:16
# 3:16

# %%
#6019
a,b,c = input().split('.')
print(c,b,a,sep='-')
# Out:
# 2020.3.4
# 4-3-2020

# %%
#6020
a,b = input().split('-')
print(a,b,sep='')
# Out:
# 000907-1121112
# 0009071121112
