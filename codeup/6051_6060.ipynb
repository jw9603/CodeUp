# %%
#6051
a,b = map(int,input().split())
print(a!=b)
# Out:
# 0 1
# True

# %%
#6052
a = int(input())
print(bool(a))
# Out:
# 0
# False

# %%
#6053
a = bool(int(input()))
print(not a)
# Out:
# 0
# True

# %%
#6054
a,b = map(int,input().split())
print(bool(a) and bool(b))
# Out:
# 1 1
# True

# %%
#6055
a,b = map(int,input().split())
print(bool(a) or bool(b))
# Out:
# 1 1
# True

# %%
#6056
a,b = map(int,input().split())
a = bool(a)
b = bool(b)
print((a and not(b))or(not(a)and b))
# Out:
# 1 1
# False

# %%
#6057
a,b = map(int,input().split())
print((bool(a)and bool(b))or(not(bool(a))and not(bool(b))))
# Out:
# 0 0
# True

# %%
#6058
a,b = map(int,input().split())
print(not(bool(a)or bool(b)))#not a and not b == not(a or b)
# Out:
# 0 0
# True

# %%
#6059
a = int(input())
print(~a)
# Out:
# 2
# -3

# %%
#6060
a,b = map(int,input().split())
print(a&b)
# Out:
# 3 5
# 1
