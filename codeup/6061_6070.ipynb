# %%
#6061
a,b = map(int,input().split())
print(a|b)
# Out:
# 3 5
# 7

# %%
#6062
a,b = map(int,input().split())
print(a^b)
# Out:
# 3 5
# 6

# %%
#6063
a,b = map(int,input().split())
print(a if a>=b else b)
# Out:
# 123 456
# 456

# %%
#6064
a,b,c = map(int,input().split())
lis = [a,b,c]
lis.sort()
print(lis[0])
# Out:
# 3 -1 5
# -1

# %%
#6064
a,b,c = map(int,input().split())
d = a if a<b else b
e = d if d<c else c
print(e)
# Out:
# 3 -1 5
# -1

# %%
#6065
a,b,c = map(int,input().split())
lis = [a,b,c]
for i in lis:
    if i%2==0:
        print(i)
    else:
        continue
# Out:
# 1 2 4
# 2
# 4

# %%
#6066
a,b,c = map(int,input().split())
lis = [a,b,c]
for i in lis:
    if i%2==0:
        print('even')
    else:
        print('odd')
# Out:
# 1 2 8
# odd
# even
# even

# %%
#6067
a = int(input())
if a<0 and a%2==0:
    print('A')
if a<0 and a%2==1:
    print('B')
if a>0 and a%2==0:
    print('C')
if a>0 and a%2==1:
    print('D')
# Out:
# -2147483648
# A

# %%
#6068
a = int(input())

if a>=90:
    print('A')
else:
    if a>=70:
        print('B')
    else:
        if a>=40:
            print('C')
        else:
            print('D')
# Out:
# 73
# B

# %%
#6069
a = input()
if a == 'A':
    print('best!!!')
else:
    if a =='B':
        print('good!!')
    else:
        if a == 'C':
            print('run!')
        else:
            if a == 'D':
                print('slowly~')
            else:
                print('what?')
# Out:
# A
# best!!!

# %%
#6070
a = int(input())
if a//3 == 1:
    print('spring')
elif a//3 == 2:
    print('summer')
elif a//3 == 3:
    print('fall')
else:
    print('winter')
# Out:
# 1
# winter
