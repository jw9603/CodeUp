# %%
#6041
a,b = map(int,input().split())
print(a%b)
# Out:
# 10 3
# 1

# %%
#6042
a = float(input())
print('{:.2f}'.format(a))
# Out:
# 3.141592
# 3.14

# %%
#6043
f1,f2 = map(float,input().split())
print('{:.3f}'.format(f1/f2))
# Out:
# 10.0 3.0
# 3.333

# %%
#6044
a,b = map(int,input().split())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print('{:.2f}'.format(a/b))
# Out:
# 10 3
# 13
# 7
# 30
# 3
# 1
# 3.33

# %%
#6045
a,b,c = map(int,input().split())
print(a+b+c,end=' ')
print('{:.2f}'.format((a+b+c)/3.))
# Out:
# 1 2 3
# 6 2.00

# %%
#6046
a = int(input())
print(a<<1)
# Out:
# 10
# 20

# %%
#6047
a,b = map(int,input().split())
print(a<<b)#a를 2^b배하여 출력
# Out:
# 2 4
# 32

# %%
#6048
a,b = map(int,input().split())
print(a<b)
# Out:
# 1 9
# True

# %%
#6049
a,b = map(int,input().split())
print(a==b)
# Out:
# 0 0
# True

# %%
#6050
a,b = map(int,input().split())
print(b>=a)
# Out:
# 0 -1
# False
